# %% [markdown]
# ## 6.7 Creating Data Dashboards

# %% [markdown]
# #### 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans

# %%
# Turn project folder path into a string
path = r'C:/Users/Marker/Desktop/World Risk Index 03-25'

# %%
path
# Out:
# 'C:/Users/Marker/Desktop/World Risk Index 03-25'

# %% [markdown]
# ### 2. Converting categorical values to ordinals

# %% [markdown]
# ##### 2.1 Import data

# %%
# Import "WRI_iso_updated.csv"
df_wri = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'WRI_iso_updated.csv'), index_col = False)

# %%
# Confirm the shape of the dataset
df_wri.shape
# Out:
# (1917, 13)

# %%
# Check a sample
df_wri.head()
# Out:
#            Country ISO_a3  Year    WRI  Exposure  Vulnerability  \
# 0          Vanuatu    VUT  2011  32.00     56.33          56.81
# 1            Tonga    TON  2011  29.08     56.04          51.90
# 2      Philippines    PHL  2011  24.32     45.09          53.93
# 3  Solomon Islands    SLB  2011  23.51     36.40          64.60
# 4        Guatemala    GTM  2011  20.88     38.42          54.35
#
#    Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 0           37.14                      79.34                        53.96
# 1           28.94                      81.80                        44.97
# 2           34.99                      82.78                        44.01
# 3           44.11                      85.95                        63.74
# 4           35.36                      77.83                        49.87
#
#   WRI Category Exposure Category Vulnerability Category  \
# 0    Very High         Very High                   High
# 1    Very High         Very High                 Medium
# 2    Very High         Very High                   High
# 3    Very High         Very High              Very High
# 4    Very High         Very High                   High
#
#   Susceptibility Category
# 0                    High
# 1                  Medium
# 2                    High
# 3                    High
# 4                    High

# %% [markdown]
# #### Convert values

# %%
# Define mapping dictionary
mapping = {'Very High': 5, 'High': 4, 'Medium': 3, 'Low': 2, 'Very Low': 1}

# Map categorical values to ordinals
df_wri = df_wri.replace(mapping)
# Out:
# C:\Users\Marker\AppData\Local\Temp\ipykernel_22336\3954765432.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_wri = df_wri.replace(mapping)

# %%
# Check a sample
df_wri.head(20)
# Out:
#               Country ISO_a3  Year    WRI  Exposure  Vulnerability  \
# 0             Vanuatu    VUT  2011  32.00     56.33          56.81
# 1               Tonga    TON  2011  29.08     56.04          51.90
# 2         Philippines    PHL  2011  24.32     45.09          53.93
# 3     Solomon Islands    SLB  2011  23.51     36.40          64.60
# 4           Guatemala    GTM  2011  20.88     38.42          54.35
# 5          Bangladesh    BGD  2011  17.45     27.52          63.41
# 6         Timor-Leste    TLS  2011  17.45     25.97          67.17
# 7          Costa Rica    CRI  2011  16.74     42.39          39.50
# 8            Cambodia    KHM  2011  16.58     26.66          62.18
# 9         El Salvador    SLV  2011  16.49     32.18          51.24
# 10          Nicaragua    NIC  2011  15.74     27.64          56.94
# 11   Papua New Guinea    PNG  2011  15.45     23.26          66.41
# 12         Madagascar    MDG  2011  14.46     20.68          69.91
# 13  Brunei Darussalam    BRN  2011  14.08     36.28          38.83
# 14        Afghanistan    AFG  2011  14.06     18.45          76.19
# 15              Niger    NER  2011  14.03     18.49          75.86
# 16             Gambia    GMB  2011  13.90     22.20          62.63
# 17             Bhutan    BTN  2011  13.65     24.63          55.42
# 18               Fiji    FJI  2011  13.57     25.87          52.48
# 19      Guinea-Bissau    GNB  2011  13.12     18.53          70.84
#
#     Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 0            37.14                      79.34                        53.96
# 1            28.94                      81.80                        44.97
# 2            34.99                      82.78                        44.01
# 3            44.11                      85.95                        63.74
# 4            35.36                      77.83                        49.87
# 5            44.96                      86.49                        58.77
# 6            52.42                      89.16                        59.93
# 7            21.96                      63.39                        33.14
# 8            48.28                      86.43                        51.81
# 9            30.55                      75.35                        47.82
# 10           41.23                      83.00                        46.59
# 11           50.04                      84.83                        64.36
# 12           67.51                      85.65                        56.57
# 13           13.48                      66.06                        36.93
# 14           61.09                      93.94                        73.55
# 15           69.38                      89.54                        68.65
# 16           45.29                      83.99                        58.62
# 17           34.56                      79.02                        52.67
# 18           36.32                      76.44                        44.67
# 19           59.51                      89.76                        63.26
#
#     WRI Category  Exposure Category  Vulnerability Category  \
# 0              5                  5                       4
# 1              5                  5                       3
# 2              5                  5                       4
# 3              5                  5                       5
# 4              5                  5                       4
# 5              5                  5                       5
# 6              5                  5                       5
# 7              5                  5                       2
# 8              5                  5                       4
# 9              5                  5                       3
# 10             5                  5                       4
# 11             5                  5                       5
# 12             5                  5                       5
# 13             5                  5                       2
# 14             5                  5                       5
# 15             5                  5                       5
# 16             5                  5                       4
# 17             5                  5                       4
# 18             5                  5                       3
# 19             5                  5                       5
#
#     Susceptibility Category
# 0                         4
# 1                         3
# 2                         4
# 3                         4
# 4                         4
# 5                         4
# 6                         5
# 7                         2
# 8                         4
# 9                         3
# 10                        4
# 11                        5
# 12                        5
# 13                        1
# 14                        5
# 15                        5
# 16                        4
# 17                        4
# 18                        4
# 19                        5

# %% [markdown]
# #### 2.2 Export  the data

# %%
# Confirm the shape of the dataset
df_wri.shape
# Out:
# (1917, 13)

# %%
# Export df_wri as "WRI_tableau.csv"
df_wri.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'WRI_tableau.csv'), index = False)

# %% [markdown]
# ### 3. Clustering

# %%
# Create a new dataframe with numerical variables only
df_num = df_wri[
    ['WRI', 'Exposure', 'Vulnerability', 
    'Susceptibility', 'Lack of Coping Capacities', 'Lack of Adaptive Capacities']
].copy()

# %%
# Create the k-means object
kmeans = KMeans(n_clusters=3)

# %%
# Fit the k-means object to the data
kmeans.fit(df_num)
# Out:
# C:\Users\Marker\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] Das System kann die angegebene Datei nicht finden
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Marker\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Marker\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Marker\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Marker\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KMeans(n_clusters=3)

# %%
# Create column containing corresponding clusters
df_wri['Clusters'] = kmeans.fit_predict(df_num)

# %%
# Check a sample
df_wri.head()
# Out:
#            Country ISO_a3  Year    WRI  Exposure  Vulnerability  \
# 0          Vanuatu    VUT  2011  32.00     56.33          56.81
# 1            Tonga    TON  2011  29.08     56.04          51.90
# 2      Philippines    PHL  2011  24.32     45.09          53.93
# 3  Solomon Islands    SLB  2011  23.51     36.40          64.60
# 4        Guatemala    GTM  2011  20.88     38.42          54.35
#
#    Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 0           37.14                      79.34                        53.96
# 1           28.94                      81.80                        44.97
# 2           34.99                      82.78                        44.01
# 3           44.11                      85.95                        63.74
# 4           35.36                      77.83                        49.87
#
#    WRI Category  Exposure Category  Vulnerability Category  \
# 0             5                  5                       4
# 1             5                  5                       3
# 2             5                  5                       4
# 3             5                  5                       5
# 4             5                  5                       4
#
#    Susceptibility Category  Clusters
# 0                        4         1
# 1                        3         0
# 2                        4         0
# 3                        4         1
# 4                        4         0

# %%
# Check the frequencies of the "Clusters" columns
df_wri['Clusters'].value_counts()
# Out:
# Clusters
# 0    773
# 1    588
# 2    556
# Name: count, dtype: int64

# %%
# Check for missing values
df_wri.isnull().sum()
# Out:
# Country                        0
# ISO_a3                         0
# Year                           0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capacities      0
# Lack of Adaptive Capacities    0
# WRI Category                   0
# Exposure Category              0
# Vulnerability Category         0
# Susceptibility Category        0
# Clusters                       0
# dtype: int64

# %% [markdown]
# #### 3.1 Export data

# %%
# Confirm the shape of the dataset
df_wri.shape
# Out:
# (1917, 14)

# %%
# Export df_num as "WRI_complete_clustered.csv"
df_wri.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'WRI_complete_clustered.csv'), index = False)

# %% [markdown]
# ## 4. Creating a correlation matrix

# %% [markdown]
# #### 4.1 Create matrix

# %%
# Create a subset for continuous variables
df_cont = df_wri[
    ['WRI', 'Exposure', 'Vulnerability', 'Susceptibility',
     'Lack of Coping Capacities', 'Lack of Adaptive Capacities']
]

# %%
# Create a correlation matrix
df_matrix = df_cont.corr()

df_matrix
# Out:
#                                   WRI  Exposure  Vulnerability  \
# WRI                          1.000000  0.917488       0.445140
# Exposure                     0.917488  1.000000       0.106925
# Vulnerability                0.445140  0.106925       1.000000
# Susceptibility               0.380923  0.065290       0.935944
# Lack of Coping Capacities    0.458327  0.147847       0.930961
# Lack of Adaptive Capacities  0.413403  0.087742       0.945379
#
#                              Susceptibility  Lack of Coping Capacities  \
# WRI                                0.380923                   0.458327
# Exposure                           0.065290                   0.147847
# Vulnerability                      0.935944                   0.930961
# Susceptibility                     1.000000                   0.784190
# Lack of Coping Capacities          0.784190                   1.000000
# Lack of Adaptive Capacities        0.838044                   0.833058
#
#                              Lack of Adaptive Capacities
# WRI                                             0.413403
# Exposure                                        0.087742
# Vulnerability                                   0.945379
# Susceptibility                                  0.838044
# Lack of Coping Capacities                       0.833058
# Lack of Adaptive Capacities                     1.000000

# %% [markdown]
# #### 4.2 Export the data

# %%
# Confirm the shape of the dataset
df_matrix.shape
# Out:
# (6, 6)

# %%
# Export df_matrix as "WRI_matrix.csv"
df_matrix.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'WRI_matrix.csv'))

# %% [markdown]
# ## 5. Merging temperature dataframes

# %% [markdown]
# #### Import data

# %%
# Import "temp_anomalies_smoothed.csv"
df_temp_1 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'temp_anomalies_prepared.csv'))

# %%
# Confirm the shape of the dataset
df_temp_1.shape
# Out:
# (278, 2)

# %%
# Check a sample
df_temp_1.head()
# Out:
#          Date  Anomaly
# 0  2001-01-01     0.45
# 1  2001-02-01     0.43
# 2  2001-03-01     0.55
# 3  2001-04-01     0.53
# 4  2001-05-01     0.57

# %%
# Import "temp_anomalies_smoothed.csv"
df_temp_2 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'temp_anomalies_smoothed.csv'))

# %%
# Confirm the shape of the dataset
df_temp_2.shape
# Out:
# (278, 2)

# %%
# Check a sample
df_temp_2.head()
# Out:
#          Date  Anomaly Moving Average
# 0  2001-01-01                0.450000
# 1  2001-02-01                0.440000
# 2  2001-03-01                0.476667
# 3  2001-04-01                0.490000
# 4  2001-05-01                0.506000

# %% [markdown]
# #### Change data types

# %%
# Convert 'Date' column to datetime format
df_temp_1['Date'] = pd.to_datetime(df_temp_1['Date'])

# %%
# Check a sample
df_temp_1.head()
# Out:
#         Date  Anomaly
# 0 2001-01-01     0.45
# 1 2001-02-01     0.43
# 2 2001-03-01     0.55
# 3 2001-04-01     0.53
# 4 2001-05-01     0.57

# %%
# Check metadata
df_temp_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     278 non-null    datetime64[ns]
#  1   Anomaly  278 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.5 KB

# %%
# Convert 'Date' column to datetime format
df_temp_2['Date'] = pd.to_datetime(df_temp_2['Date'])

# %%
# Check a sample
df_temp_2.head()
# Out:
#         Date  Anomaly Moving Average
# 0 2001-01-01                0.450000
# 1 2001-02-01                0.440000
# 2 2001-03-01                0.476667
# 3 2001-04-01                0.490000
# 4 2001-05-01                0.506000

# %%
# Check metadata
df_temp_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    278 non-null    datetime64[ns]
#  1   Anomaly Moving Average  278 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.5 KB

# %% [markdown]
# ### 5.1 Merging dataframes

# %%
# Merge the DataFrames on the 'Date' column
temp_merged = pd.merge(df_temp_1, df_temp_2, on='Date', how='inner')

# %%
# Check a sample
temp_merged.head()
# Out:
#         Date  Anomaly  Anomaly Moving Average
# 0 2001-01-01     0.45                0.450000
# 1 2001-02-01     0.43                0.440000
# 2 2001-03-01     0.55                0.476667
# 3 2001-04-01     0.53                0.490000
# 4 2001-05-01     0.57                0.506000

# %% [markdown]
# ### 5.2 Export  the data

# %%
# Confirm the shape of the dataset
temp_merged.shape
# Out:
# (278, 3)

# %%
# Export temp_merged as "temp_anomalies_tableau.csv"
temp_merged.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'temp_anomalies_tableau.csv'), index = False)

# %% [markdown]
# ## 6. Merging WRI & HDI dataframes

# %% [markdown]
# ####  6.1 Import data

# %%
# Import "HDI_prepared.csv"
df_hdi = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'HDI_prepared.csv'), index_col = False)

# %%
# Confirm the shape of the dataset
df_hdi.shape
# Out:
# (206, 1076)

# %%
# Check a sample
df_hdi.head()
# Out:
#   iso3      country    hdicode region  hdi_rank_2022  hdi_1990  hdi_1991  \
# 0  AFG  Afghanistan        Low     SA          182.0     0.284     0.292
# 1  ALB      Albania       High    ECA           74.0     0.649     0.632
# 2  DZA      Algeria       High     AS           93.0     0.593     0.596
# 3  AND      Andorra  Very High    NaN           35.0       NaN       NaN
# 4  AGO       Angola     Medium    SSA          150.0       NaN       NaN
#
#    hdi_1992  hdi_1993  hdi_1994  ...  pop_total_2013  pop_total_2014  \
# 0     0.299     0.307     0.300  ...       31.541208       32.716210
# 1     0.616     0.618     0.623  ...        2.887014        2.884102
# 2     0.601     0.602     0.603  ...       38.000627       38.760168
# 3       NaN       NaN       NaN  ...        0.071366        0.071622
# 4       NaN       NaN       NaN  ...       26.147002       27.128336
#
#    pop_total_2015  pop_total_2016  pop_total_2017  pop_total_2018  \
# 0       33.753499       34.636207       35.643417       36.686784
# 1        2.882480        2.881063        2.879355        2.877013
# 2       39.543154       40.339329       41.136546       41.927007
# 3        0.071746        0.072540        0.073836        0.075013
# 4       28.127721       29.154746       30.208628       31.273533
#
#    pop_total_2019  pop_total_2020  pop_total_2021  pop_total_2022
# 0       37.769498       38.972231       40.099462       41.128771
# 1        2.873883        2.866849        2.854710        2.842321
# 2       42.705368       43.451666       44.177968       44.903225
# 3        0.076343        0.077700        0.079034        0.079824
# 4       32.353588       33.428486       34.503774       35.588987
#
# [5 rows x 1076 columns]

# %% [markdown]
# #### 6.2 Merging dataframes

# %%
# Convert the 'year' column in df_wri to string type
df_wri['Year'] = df_wri['Year'].astype(str)

# Define the columns to merge from df_hdi
columns_to_merge = ['iso3'] + [f'hdi_{year}' for year in range(2011, 2022)]

# Melt the df_hdi DataFrame to transpose HDI values into rows
melted_hdi = df_hdi.melt(id_vars='iso3', value_vars=columns_to_merge[1:], var_name='year', value_name='HDI')

# Extract the year from the 'year' column
melted_hdi['year'] = melted_hdi['year'].str.split('_').str[-1]

# Merge the melted_hdi DataFrame with df_wri based on 'iso3' and 'year'
df_wri_hdi = pd.merge(df_wri, melted_hdi, left_on=['ISO_a3', 'Year'], right_on=['iso3', 'year'], how='inner')

# Drop redundant 'iso3' column after merge
df_wri_hdi.drop(columns=['iso3', 'year'], inplace=True)

# %%
# Confirm the shape of the dataset
df_wri_hdi.shape
# Out:
# (1917, 15)

# %%
# Check a sample
df_wri_hdi.head()
# Out:
#            Country ISO_a3  Year    WRI  Exposure  Vulnerability  \
# 0          Vanuatu    VUT  2011  32.00     56.33          56.81
# 1            Tonga    TON  2011  29.08     56.04          51.90
# 2      Philippines    PHL  2011  24.32     45.09          53.93
# 3  Solomon Islands    SLB  2011  23.51     36.40          64.60
# 4        Guatemala    GTM  2011  20.88     38.42          54.35
#
#    Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 0           37.14                      79.34                        53.96
# 1           28.94                      81.80                        44.97
# 2           34.99                      82.78                        44.01
# 3           44.11                      85.95                        63.74
# 4           35.36                      77.83                        49.87
#
#    WRI Category  Exposure Category  Vulnerability Category  \
# 0             5                  5                       4
# 1             5                  5                       3
# 2             5                  5                       4
# 3             5                  5                       5
# 4             5                  5                       4
#
#    Susceptibility Category  Clusters    HDI
# 0                        4         1  0.581
# 1                        3         0  0.716
# 2                        4         0  0.677
# 3                        4         1  0.557
# 4                        4         0  0.617

# %%
# Check for missing values
df_wri_hdi.isnull().sum()
# Out:
# Country                        0
# ISO_a3                         0
# Year                           0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capacities      0
# Lack of Adaptive Capacities    0
# WRI Category                   0
# Exposure Category              0
# Vulnerability Category         0
# Susceptibility Category        0
# Clusters                       0
# HDI                            0
# dtype: int64

# %% [markdown]
# #### 6.3 Export the data

# %%
# Confirm the shape of the dataset
df_wri_hdi.shape
# Out:
# (1917, 15)

# %%
# Export df as "WRI_HDI_combined.csv"
df_wri_hdi.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'WRI_HDI_combined.csv'), index = False)
